# %%
import matplotlib.pyplot as plt

steps = [10, 20, 30, 40, 50, 60, 70, 80, 100]
#colors = ["#6F2DBD", "#D92567", "#0476D9", "#05A63D", "#F29F05"]
colors = ["#F29F05", "#0476D9", "#D92567", "#099B3C", "#6F2DBD"]

rmse_data_by_task = {
    "A": {
        "FedAvg":     [19.419577, 18.946984, 18.451729, 17.786949, 17.789124, 18.406540, 18.100772, 18.025117, 18.257229],
        "SCAFFOLD":   [19.337322, 18.880615, 18.382611, 17.643676, 16.872027, 16.846107, 16.268868, 16.326960, 16.358008],
        "FedProx":    [19.419577, 18.946984, 18.451729, 17.786949, 17.789124, 18.406540, 18.100772, 18.025117, 18.257229],
        "FedDyn":     [30.147742, 28.714932, 27.790929, 25.510064, 29.205013, 23.371999, 21.900115, 21.508321, 22.473387],
        "FedCross":   [21.200460, 20.642993, 20.691406, 20.470530, 19.998353, 20.147107, 19.761227, 19.882417, 19.351121],
    },

    "B": {
        "FedAvg":     [51.203554, 45.957908, 42.258745, 42.308548, 40.435734, 38.644455, 36.840418, 35.360877, 31.824605],
        "SCAFFOLD":   [35.418847, 33.364554, 20.498832, 17.519931, 17.887925, 17.864946, 17.996636, 17.911406, 18.225719],
        "FedProx":    [37.952376, 40.727542, 37.916074, 39.637353, 39.165174, 35.354989, 33.343432, 34.698094, 32.699147],
        "FedDyn":     [37.952376, 40.727542, 37.916074, 39.637353, 39.165174, 35.354989, 33.343432, 34.698094, 32.699147],
        "FedCross":   [16.859077, 16.080107, 15.574151, 15.432130, 15.254264, 15.316773, 15.483599, 15.832549, 16.389745],
    },

    "C": {
        "FedAvg":     [29.170027, 28.607743, 28.946246, 29.338664, 29.562037, 29.689112, 29.822843, 29.947040, 30.117488],
        "SCAFFOLD":   [29.542337, 31.024262, 29.626671, 38.116082, 29.353429, 28.833743, 28.590078, 29.028789, 29.699329],
        "FedProx":    [29.170027, 28.607743, 28.946246, 29.338664, 29.562037, 29.689112, 29.822843, 29.947040, 30.117488],
        "FedDyn":     [44.423821, 32.050004, 43.409757, 35.744963, 31.890137, 35.002981, 32.699660, 32.207218, 32.590449],
        "FedCross":   [19.948642, 19.382323, 18.616644, 17.719729, 17.699083, 17.511957, 17.573432, 17.747408, 17.970567],
    },

    "D": {
        "FedAvg":     [15.784029, 14.715542, 14.616571, 14.337863, 14.506531, 14.506618, 14.355641, 14.251670, 14.063740],
        "SCAFFOLD":   [16.200155, 15.326888, 14.767970, 14.107286, 13.352676, 12.791533, 12.477654, 12.374992, 12.326882],
        "FedProx":    [28.006033, 38.466775, 30.998026, 25.203364, 31.003257, 31.146018, 25.107165, 20.829922, 26.539980],
        "FedDyn":     [28.006033, 38.466775, 30.998026, 25.203364, 31.003257, 31.146018, 25.107165, 20.829922, 26.539980],
        "FedCross":   [16.174101, 15.161410, 14.355823, 13.467845, 12.806052, 12.716078, 12.665013, 12.529042, 12.596079],
    },

    "E": {
        "FedAvg":     [29.060157, 29.179215, 29.149693, 29.080535, 29.006054, 28.941019, 28.889754, 28.859334, 28.870869],
            30.300659451311102, 26.502144404249904, 20.693416308886462, 19.032279204342146,
            18.217857834214954, 17.687549916289615, 17.34654212101589, 17.515400070461183,
            17.22358489707429, 16.671418541031205, 16.410523426840147, 16.213749707086897,
            16.036982847233883, 15.849731629813457, 15.694960594319532, 15.550477922000653,
            15.449310685502187, 15.325297469974574, 15.265146762469481, 15.175571680198104
        ],
        "FedDyn": [
            39.78685685438039, 39.492971676585135, 39.097292354848435, 38.66183211690192,
            38.215114052677485, 37.80735202024112, 37.435801185531616, 37.11688210212791,
            36.845849706669284, 36.62053888297207, 36.48640368529768, 36.441016025040476,
            36.447990703753426, 36.44250850939867, 36.35149750411873, 36.197546731210736,
            36.03375334626232, 35.89226008237019, 35.77970950772473, 35.73290794219519
        ],
        "FedCross": [
            30.338316896173048, 27.17307173985814, 21.272886664811054, 18.791694523392678,
            17.74902374456683, 17.081007335450135, 16.710783252938846, 16.32571905810023,
            16.044483694755584, 15.75195202441992, 15.478512133543534, 15.217938033470775,
            15.04027229813004, 14.918263497853534, 14.826601281101686, 14.684731466701512,
            14.635055089280556, 14.572718839773268, 14.483760608877136, 14.444865576970455
        ],
    },
    "E": {
        "FedAvg": [
            37.0165014371006, 37.01322067365897, 37.06193634919034, 37.07136377310101,
            37.02223084620757, 36.620730988365956, 35.02781837039117, 34.8249813403697,
            34.64778860433569, 34.19266564163707, 33.32114907614685, 32.635171414991376,
            32.95174537329558, 33.124525572949935, 33.13230651554156, 33.09474570859436,
            33.05521880211996, 33.01802069725854, 32.98269382064833, 32.9522127664463
        ],
        "SCAFFOLD": [
            37.30255696982621, 37.34353799012742, 37.354703602666156, 37.29062518229092,
            37.19363458007108, 37.076832228377555, 36.91555643879488, 36.40970949965879,
            35.06815139602642, 34.843778310589215, 34.69873871413442, 34.336448323292075,
            33.45607859376583, 33.06509904030831, 33.46776509938351, 33.692599361070364,
            33.59039107640981, 33.46744757975139, 33.399850440417175, 33.36732053422355
        ],
        "FedDyn": [
            41.54993735930277, 40.550896679741896, 39.455482309360676, 38.79536433858259,
            38.84757626082722, 39.25614274275676, 39.64695198961107, 39.948807487220115,
            40.191242219634326, 40.40093360778031, 40.585704991625505, 40.7398236048267,
            40.86959113779646, 40.97738272919323, 41.06004722353291, 41.102636719361506,
            41.06682780130821, 40.887944834062225, 40.491515967109514, 39.810744721206035
        ],
        "FedCross": [
            37.323758680686836, 37.39587293003071, 37.39583062341794, 37.398859815844375,
            37.30971121458594, 37.22404018420268, 37.05903368327617, 36.30648438034184,
            35.44712958126343, 35.355398642299356, 35.0638203449667, 34.393047604047794,
            33.68824576156293, 34.03875494142956, 34.344401395935826, 34.431200633082746,
            34.438295458319516, 34.288779665469065, 34.329257149244484, 34.27009214028526
        ],
    }
}

# %% [markdown]
# ### Task A

# %%
plt.figure(figsize=(8, 5))

for i, (algo, values) in enumerate(rmse_data_by_task["A"].items()):
    std_values = rmse_std_by_task["A"].get(algo)
    std_values = None
    line_color = colors[i % len(colors)]
    if std_values is not None:
        plt.errorbar(steps, values, yerr=std_values, marker="o", capsize=4, label=algo, linewidth=1.8, color=line_color)
    else:
        plt.plot(steps, values, marker="o", label=algo, linewidth=1.8, color=line_color)



plt.xlabel("Rounds", fontsize=23)
plt.ylabel("RMSE", fontsize=23)
#plt.title("Task A")
plt.xticks(steps)
plt.tick_params(axis='both', labelsize=14)
plt.grid(True, linestyle="--", alpha=0.3)
plt.legend(fontsize=18, columnspacing=1, handletextpad=0.4, framealpha=0.94)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task B

# %%
plt.figure(figsize=(8, 5))

for i, (algo, values) in enumerate(rmse_data_by_task["B"].items()):
    std_values = rmse_std_by_task["B"].get(algo)
    std_values = None
    line_color = colors[i % len(colors)]
    if std_values is not None:
        plt.errorbar(steps, values, yerr=std_values, marker="o", capsize=4, label=algo, linewidth=1.8, color=line_color)
    else:
        plt.plot(steps, values, marker="o", label=algo, linewidth=1.8, color=line_color)



plt.xlabel("Rounds", fontsize=23)
plt.ylabel("RMSE", fontsize=23)
#plt.title("Task B")
plt.xticks(steps)
plt.tick_params(axis='both', labelsize=14)
plt.grid(True, linestyle="--", alpha=0.3)
#plt.legend(fontsize=13, columnspacing=1, handletextpad=0.4, framealpha=0.94)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task C

# %%
plt.figure(figsize=(8, 5))

for i, (algo, values) in enumerate(rmse_data_by_task["C"].items()):
    std_values = rmse_std_by_task["C"].get(algo)
    std_values = None
    line_color = colors[i % len(colors)]
    if std_values is not None:
        plt.errorbar(steps, values, yerr=std_values, marker="o", capsize=4, label=algo, linewidth=1.8, color=line_color)
    else:
        plt.plot(steps, values, marker="o", label=algo, linewidth=1.8, color=line_color)

plt.xlabel("Rounds", fontsize=23)
plt.ylabel("RMSE", fontsize=23)
#plt.title("Task C")
plt.xticks(steps)
plt.tick_params(axis='both', labelsize=14)
plt.grid(True, linestyle="--", alpha=0.3)
#plt.legend(fontsize=13, columnspacing=1, handletextpad=0.4, framealpha=0.94)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task D

# %%
plt.figure(figsize=(8, 5))

for i, (algo, values) in enumerate(rmse_data_by_task["D"].items()):
    std_values = rmse_std_by_task["D"].get(algo)
    std_values = None
    line_color = colors[i % len(colors)]
    if std_values is not None:
        plt.errorbar(steps, values, yerr=std_values, marker="o", capsize=4, label=algo, linewidth=1.8, color=line_color)
    else:
        plt.plot(steps, values, marker="o", label=algo, linewidth=1.8, color=line_color)

plt.xlabel("Rounds", fontsize=23)
plt.ylabel("RMSE", fontsize=23)
#plt.title("Task D")
plt.xticks(steps)
plt.tick_params(axis='both', labelsize=14)
plt.grid(True, linestyle="--", alpha=0.3)
#plt.legend(fontsize=13, columnspacing=1, handletextpad=0.4, framealpha=0.94)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task E

# %%
plt.figure(figsize=(8, 5))

for i, (algo, values) in enumerate(rmse_data_by_task["E"].items()):
    std_values = rmse_std_by_task["E"].get(algo)
    std_values = None
    line_color = colors[i % len(colors)]
    if std_values is not None:
        plt.errorbar(steps, values, yerr=std_values, marker="o", capsize=4, label=algo, linewidth=1.8, color=line_color)
    else:
        plt.plot(steps, values, marker="o", label=algo, linewidth=1.8, color=line_color)

plt.xlabel("Rounds", fontsize=23)
plt.ylabel("RMSE", fontsize=23)
#plt.title("Task E")
plt.xticks(steps)
plt.tick_params(axis='both', labelsize=14)
plt.grid(True, linestyle="--", alpha=0.3)
#plt.legend(fontsize=13, columnspacing=1, handletextpad=0.4, framealpha=0.94)
plt.tight_layout()
plt.show()
